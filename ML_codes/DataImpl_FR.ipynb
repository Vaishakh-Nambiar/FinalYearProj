# %% [markdown]
# --------------------------------------------------------------------

# %% [markdown]
# # Trying logic:

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('/content/drive/MyDrive/V Sem7/End-Sem Project/Data/Material 1/finalyrdata_1.xlsx')
df_actual_values = pd.read_excel('/content/drive/MyDrive/V Sem7/End-Sem Project/Data/Material 1/finalyrdata_2.xlsx')

# actual_vibration_11th_day = df_actual_values[['Vibration_X', 'Vibration_Y', 'Vibration_Z']].values
# actual_vibration_11th_day = df_actual_values[['Vibration_X', 'Vibration_Y', 'Vibration_Z']].values

# %%
# Split the data into features (X) and target variables (y_vibration, y_temperature)
X = df[['Vibration_X', 'Vibration_Y', 'Vibration_Z']]
y_vibration = X  # Assuming vibration values are similar to the input features
y_temperature = df['Temperature']

# %%
# Trial
# Create linear regression models
model_vibration = LinearRegression()
model_temperature = LinearRegression()

# Train the models
model_vibration.fit(X, y_vibration)
model_temperature.fit(X, y_temperature)


# Predict the 11th day values for all 1200 records
vibration_11th_day_prediction = model_vibration.predict(X)
temperature_11th_day_prediction = model_temperature.predict(X)

# Actual values for the 11th day
# actual_vibration_11th_day = np.array([[-2.51,5,-1021]])  # Replace with the actual values
actual_vibration_11th_day = df_actual_values[['Vibration_X', 'Vibration_Y', 'Vibration_Z']].values
actual_temperature_11th_day = df_actual_values['Temperature']  # Replace with the actual value

vibration_error = np.abs(vibration_11th_day_prediction[0] - actual_vibration_11th_day)
temperature_error = np.abs(temperature_11th_day_prediction[0] - actual_temperature_11th_day)

# Calculate mean errors
mean_vibration_error = vibration_error.mean(axis=0)
mean_temperature_error = temperature_error.mean()

# Display results
print("Linear Regression - Actual Vibration on the 11th day: \n", actual_vibration_11th_day)
print("Linear Regression - Predicted Vibration on the 11th day: \n", vibration_11th_day_prediction[0])
print("Linear Regression - Vibration Error for the 11th day: \n", vibration_error)
print("Linear Regression - Mean Vibration Error for the 11th day: \n", mean_vibration_error)

print("\nLinear Regression - Actual Temperature on the 11th day: \n", actual_temperature_11th_day)
print("Linear Regression - Predicted Temperature on the 11th day: \n", temperature_11th_day_prediction[0])
print("Linear Regression - Temperature Error for the 11th day: \n", temperature_error)
print("Linear Regression - Mean Temperature Error for the 11th day: \n", mean_temperature_error)
# Out:
# Linear Regression - Actual Vibration on the 11th day:
#  [[    1.69    12.06 -1028.63]
#  [   -7.66    14.37 -1028.32]
#  [   -1.13    10.25 -1028.11]
#  ...
#  [   -1.66     6.28 -1028.14]
#  [   -1.98     9.66 -1022.77]
#  [   -1.86    34.75 -1019.18]]
# Linear Regression - Predicted Vibration on the 11th day:
#  [   -2.68    23.09 -1014.33]
# Linear Regression - Vibration Error for the 11th day:
#  [[ 4.37 11.03 14.3 ]
#  [ 4.98  8.72 13.99]
#  [ 1.55 12.84 13.78]
#  ...
#  [ 1.02 16.81 13.81]
#  [ 0.7  13.43  8.44]
#  [ 0.82 11.66  4.85]]
# Linear Regression - Mean Vibration Error for the 11th day:
#  [9.24011667 7.68758333 6.85400833]
#
# Linear Regression - Actual Temperature on the 11th day:
#  0       26.45
# 1       31.60
# 2       28.22
# 3       30.94
# 4       27.73
#         ...
# 1195    30.33
# 1196    26.44
# 1197    25.97
# 1198    25.68
# 1199    28.17
# Name: Temperature, Length: 1200, dtype: float64
# Linear Regression - Predicted Temperature on the 11th day:
#  29.10503617452745
# Linear Regression - Temperature Error for the 11th day:
#  0       2.655036
# 1       2.494964
# 2       0.885036
# 3       1.834964
# 4       1.375036
#           ...
# 1195    1.224964
# 1196    2.665036
# 1197    3.135036
# 1198    3.425036
# 1199    0.935036
# Name: Temperature, Length: 1200, dtype: float64
# Linear Regression - Mean Temperature Error for the 11th day:
#  2.021884720023553

# %%
from sklearn.ensemble import RandomForestRegressor

# Create random forest models
model_vibration = RandomForestRegressor()
model_temperature = RandomForestRegressor()

# %%
model_vibration.fit(X, y_vibration)
model_temperature.fit(X, y_temperature)

# Predict the 11th day values
vibration_11th_day_prediction = model_vibration.predict(X.iloc[[-1]])
temperature_11th_day_prediction = model_temperature.predict(X.iloc[[-1]])

actual_vibration_11th_day = df_actual_values[['Vibration_X', 'Vibration_Y', 'Vibration_Z']].values
actual_temperature_11th_day = df_actual_values['Temperature']  # Replace with the actual value

vibration_error = np.abs(vibration_11th_day_prediction[0] - actual_vibration_11th_day)
temperature_error = np.abs(temperature_11th_day_prediction[0] - actual_temperature_11th_day)

# Calculate mean errors
mean_vibration_error = vibration_error.mean(axis=0)
mean_temperature_error = temperature_error.mean()

# Display results
print("RFG - Actual Vibration on the 11th day: \n", actual_vibration_11th_day)
print("RFG - Predicted Vibration on the 11th day: \n", vibration_11th_day_prediction[0])
print("RFG - Vibration Error for the 11th day: \n", vibration_error)
print("RFG - Mean Vibration Error for the 11th day: \n", mean_vibration_error)

print("\nRFG - Actual Temperature on the 11th day: \n", actual_temperature_11th_day)
print("RFG - Predicted Temperature on the 11th day: \n", temperature_11th_day_prediction[0])
print("RFG - Temperature Error for the 11th day: \n", temperature_error)
print("RFG - Mean Temperature Error for the 11th day: \n", mean_temperature_error)
# Out:
# RFG - Actual Vibration on the 11th day:
#  [[    1.69    12.06 -1028.63]
#  [   -7.66    14.37 -1028.32]
#  [   -1.13    10.25 -1028.11]
#  ...
#  [   -1.66     6.28 -1028.14]
#  [   -1.98     9.66 -1022.77]
#  [   -1.86    34.75 -1019.18]]
# RFG - Predicted Vibration on the 11th day:
#  [  -23.2189    26.5809 -1028.2292]
# RFG - Vibration Error for the 11th day:
#  [[24.9089 14.5209  0.4008]
#  [15.5589 12.2109  0.0908]
#  [22.0889 16.3309  0.1192]
#  ...
#  [21.5589 20.3009  0.0892]
#  [21.2389 16.9209  5.4592]
#  [21.3589  8.1691  9.0492]]
# RFG - Mean Vibration Error for the 11th day:
#  [13.3686135   8.8921155   7.78050433]
#
# RFG - Actual Temperature on the 11th day:
#  0       26.45
# 1       31.60
# 2       28.22
# 3       30.94
# 4       27.73
#         ...
# 1195    30.33
# 1196    26.44
# 1197    25.97
# 1198    25.68
# 1199    28.17
# Name: Temperature, Length: 1200, dtype: float64
# RFG - Predicted Temperature on the 11th day:
#  27.265000000000022
# RFG - Temperature Error for the 11th day:
#  0       0.815
# 1       4.335
# 2       0.955
# 3       3.675
# 4       0.465
#         ...
# 1195    3.065
# 1196    0.825
# 1197    1.295
# 1198    1.585
# 1199    0.905
# Name: Temperature, Length: 1200, dtype: float64
# RFG - Mean Temperature Error for the 11th day:
#  2.385916666666657

# %%
from xgboost import XGBRegressor

# Create XGBoost models
model_vibration = XGBRegressor()
model_temperature = XGBRegressor()

# ... (rest of the code is similar to Linear Regression)

# %%
model_vibration.fit(X, y_vibration)
model_temperature.fit(X, y_temperature)

# Predict the 11th day values
vibration_11th_day_prediction = model_vibration.predict(X.iloc[[-1]])
temperature_11th_day_prediction = model_temperature.predict(X.iloc[[-1]])

# Actual values for the 11th day
actual_vibration_11th_day = df_actual_values[['Vibration_X', 'Vibration_Y', 'Vibration_Z']].values
actual_temperature_11th_day = df_actual_values['Temperature']  # Replace with the actual value

vibration_error = np.abs(vibration_11th_day_prediction[0] - actual_vibration_11th_day)
temperature_error = np.abs(temperature_11th_day_prediction[0] - actual_temperature_11th_day)

# Calculate mean errors
mean_vibration_error = vibration_error.mean(axis=0)
mean_temperature_error = temperature_error.mean()

# Display results
print("XGBoost - Actual Vibration on the 11th day: \n", actual_vibration_11th_day)
print("XGBoost - Predicted Vibration on the 11th day: \n", vibration_11th_day_prediction[0])
print("XGBoost - Vibration Error for the 11th day: \n", vibration_error)
print("XGBoost - Mean Vibration Error for the 11th day: \n", mean_vibration_error)

print("\nXGBoost - Actual Temperature on the 11th day: \n", actual_temperature_11th_day)
print("XGBoost - Predicted Temperature on the 11th day: \n", temperature_11th_day_prediction[0])
print("XGBoost - Temperature Error for the 11th day: \n", temperature_error)
print("XGBoost - Mean Temperature Error for the 11th day: \n", mean_temperature_error)
# Out:
# XGBoost - Actual Vibration on the 11th day:
#  [[    1.69    12.06 -1028.63]
#  [   -7.66    14.37 -1028.32]
#  [   -1.13    10.25 -1028.11]
#  ...
#  [   -1.66     6.28 -1028.14]
#  [   -1.98     9.66 -1022.77]
#  [   -1.86    34.75 -1019.18]]
# XGBoost - Predicted Vibration on the 11th day:
#  [  -23.348892    26.688473 -1028.9445  ]
# XGBoost - Vibration Error for the 11th day:
#  [[25.03889221 14.62847275  0.31445801]
#  [15.68889221 12.31847275  0.62445801]
#  [22.21889221 16.43847275  0.83445801]
#  ...
#  [21.68889221 20.40847275  0.80445801]
#  [21.36889221 17.02847275  6.17445801]
#  [21.48889221  8.06152725  9.76445801]]
# XGBoost - Mean Vibration Error for the 11th day:
#  [13.48397704  8.94195395  8.37799805]
#
# XGBoost - Actual Temperature on the 11th day:
#  0       26.45
# 1       31.60
# 2       28.22
# 3       30.94
# 4       27.73
#         ...
# 1195    30.33
# 1196    26.44
# 1197    25.97
# 1198    25.68
# 1199    28.17
# Name: Temperature, Length: 1200, dtype: float64
# XGBoost - Predicted Temperature on the 11th day:
#  26.011068
# XGBoost - Temperature Error for the 11th day:
#  0       0.438932
# 1       5.588932
# 2       2.208932
# 3       4.928932
# 4       1.718932
#           ...
# 1195    4.318932
# 1196    0.428932
# 1197    0.041068
# 1198    0.331068
# 1199    2.158932
# Name: Temperature, Length: 1200, dtype: float64
# XGBoost - Mean Temperature Error for the 11th day:
#  3.1143373449961342

# %%
#LSTM models
from keras.models import Sequential
from keras.layers import LSTM, Dense

# Create LSTM models
model_vibration = Sequential()
model_temperature = Sequential()

# Add LSTM layers to the models
model_vibration.add(LSTM(units=50, activation='relu', input_shape=(X.shape[1], 1)))
model_vibration.add(Dense(units=X.shape[1]))  # Output layer for vibration

model_temperature.add(LSTM(units=50, activation='relu', input_shape=(X.shape[1], 1)))
model_temperature.add(Dense(units=1))  # Output layer for temperature

# Compile the models
model_vibration.compile(optimizer='adam', loss='mean_squared_error')
model_temperature.compile(optimizer='adam', loss='mean_squared_error')

# Reshape the input data for LSTM
X_lstm = np.array(X).reshape(X.shape[0], X.shape[1], 1)

# Train the models
model_vibration.fit(X_lstm, y_vibration, epochs=100, batch_size=32)
model_temperature.fit(X_lstm, y_temperature, epochs=100, batch_size=32)

# Predict the 11th day values
X_11th_day = np.array(X.iloc[[-1]]).reshape(1, X.shape[1], 1)
vibration_11th_day_prediction = model_vibration.predict(X_11th_day)
temperature_11th_day_prediction = model_temperature.predict(X_11th_day)


# Actual values for the 11th day
# actual_vibration_11th_day = np.array([[-2.51,5,-1021]])  # Replace with the actual values
actual_vibration_11th_day = df_actual_values[['Vibration_X', 'Vibration_Y', 'Vibration_Z']].values
actual_temperature_11th_day = df_actual_values['Temperature']  # Replace with the actual value

vibration_error = np.abs(vibration_11th_day_prediction[0] - actual_vibration_11th_day)
temperature_error = np.abs(temperature_11th_day_prediction[0] - actual_temperature_11th_day)

# Calculate mean errors
mean_vibration_error = vibration_error.mean(axis=0)
mean_temperature_error = temperature_error.mean()

# Display results
print("LSTM - Actual Vibration on the 11th day:\n", actual_vibration_11th_day)
print("LSTM - Predicted Vibration on the 11th day:\n", vibration_11th_day_prediction[0])
print("LSTM - Vibration Error for the 11th day:\n", vibration_error)
print("LSTM - Mean Vibration Error for the 11th day: \n", mean_vibration_error)

print("\nLSTM - Actual Temperature on the 11th day:\n", actual_temperature_11th_day)
print("LSTM - Predicted Temperature on the 11th day:\n", temperature_11th_day_prediction[0][0])
print("LSTM - Temperature Error for the 11th day:\n", temperature_error)
print("LSTM - Mean Temperature Error for the 11th day: \n", mean_temperature_error)
# Out:
# Epoch 1/100
# 38/38 [==============================] - 1s 2ms/step - loss: 250188.9531
# Epoch 2/100
# 38/38 [==============================] - 0s 2ms/step - loss: 162056.2500
# Epoch 3/100
# 38/38 [==============================] - 0s 2ms/step - loss: 43133.1719
# Epoch 4/100
# 38/38 [==============================] - 0s 2ms/step - loss: 1441.1653
# Epoch 5/100
# 38/38 [==============================] - 0s 2ms/step - loss: 563.1345
# Epoch 6/100
# 38/38 [==============================] - 0s 2ms/step - loss: 314.3326
# Epoch 7/100
# 38/38 [==============================] - 0s 2ms/step - loss: 175.6313
# Epoch 8/100
# 38/38 [==============================] - 0s 2ms/step - loss: 100.9395
# Epoch 9/100
# 38/38 [==============================] - 0s 2ms/step - loss: 70.8356
# Epoch 10/100
# 38/38 [==============================] - 0s 2ms/step - loss: 57.4343
# Epoch 11/100
# 38/38 [==============================] - 0s 2ms/step - loss: 49.6807
# Epoch 12/100
# 38/38 [==============================] - 0s 2ms/step - loss: 42.0479
# Epoch 13/100
# 38/38 [==============================] - 0s 2ms/step - loss: 35.6974
# Epoch 14/100
# 38/38 [==============================] - 0s 2ms/step - loss: 31.7802
# Epoch 15/100
# 38/38 [==============================] - 0s 2ms/step - loss: 23.6315
# Epoch 16/100
# 38/38 [==============================] - 0s 2ms/step - loss: 19.1954
# Epoch 17/100
# 38/38 [==============================] - 0s 2ms/step - loss: 16.1733
# Epoch 18/100
# 38/38 [==============================] - 0s 2ms/step - loss: 14.4077
# Epoch 19/100
# 38/38 [==============================] - 0s 2ms/step - loss: 12.0185
# Epoch 20/100
# 38/38 [==============================] - 0s 2ms/step - loss: 11.4506
# Epoch 21/100
# 38/38 [==============================] - 0s 2ms/step - loss: 9.3651
# Epoch 22/100
# 38/38 [==============================] - 0s 2ms/step - loss: 8.1057
# Epoch 23/100
# 38/38 [==============================] - 0s 2ms/step - loss: 7.2165
# Epoch 24/100
# 38/38 [==============================] - 0s 2ms/step - loss: 8.0669
# Epoch 25/100
# 38/38 [==============================] - 0s 2ms/step - loss: 6.5809
# Epoch 26/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.8145
# Epoch 27/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.4104
# Epoch 28/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.0042
# Epoch 29/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.0830
# Epoch 30/100
# 38/38 [==============================] - 0s 2ms/step - loss: 3.9393
# Epoch 31/100
# 38/38 [==============================] - 0s 2ms/step - loss: 4.0000
# Epoch 32/100
# 38/38 [==============================] - 0s 2ms/step - loss: 3.4131
# Epoch 33/100
# 38/38 [==============================] - 0s 2ms/step - loss: 3.3518
# Epoch 34/100
# 38/38 [==============================] - 0s 2ms/step - loss: 2.8914
# Epoch 35/100
# 38/38 [==============================] - 0s 2ms/step - loss: 3.0105
# Epoch 36/100
# 38/38 [==============================] - 0s 2ms/step - loss: 2.8553
# Epoch 37/100
# 38/38 [==============================] - 0s 2ms/step - loss: 2.4326
# Epoch 38/100
# 38/38 [==============================] - 0s 2ms/step - loss: 2.5045
# Epoch 39/100
# 38/38 [==============================] - 0s 2ms/step - loss: 2.0597
# Epoch 40/100
# 38/38 [==============================] - 0s 2ms/step - loss: 1.8606
# Epoch 41/100
# 38/38 [==============================] - 0s 3ms/step - loss: 2.0633
# Epoch 42/100
# 38/38 [==============================] - 0s 2ms/step - loss: 1.7334
# Epoch 43/100
# 38/38 [==============================] - 0s 2ms/step - loss: 1.5818
# Epoch 44/100
# 38/38 [==============================] - 0s 2ms/step - loss: 1.5514
# Epoch 45/100
# 38/38 [==============================] - 0s 2ms/step - loss: 1.5225
# Epoch 46/100
# 38/38 [==============================] - 0s 2ms/step - loss: 1.3674
# Epoch 47/100
# 38/38 [==============================] - 0s 2ms/step - loss: 1.2497
# Epoch 48/100
# 38/38 [==============================] - 0s 2ms/step - loss: 1.1913
# Epoch 49/100
# 38/38 [==============================] - 0s 2ms/step - loss: 1.2729
# Epoch 50/100
# 38/38 [==============================] - 0s 2ms/step - loss: 1.4182
# Epoch 51/100
# 38/38 [==============================] - 0s 2ms/step - loss: 1.2988
# Epoch 52/100
# 38/38 [==============================] - 0s 2ms/step - loss: 1.1205
# Epoch 53/100
# 38/38 [==============================] - 0s 2ms/step - loss: 1.1189
# Epoch 54/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.9530
# Epoch 55/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.8188
# Epoch 56/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.7744
# Epoch 57/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.8256
# Epoch 58/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.7305
# Epoch 59/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5910
# Epoch 60/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5108
# Epoch 61/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.6725
# Epoch 62/100
# 38/38 [==============================] - 0s 2ms/step - loss: 1.1172
# Epoch 63/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.7048
# Epoch 64/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.6572
# Epoch 65/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4242
# Epoch 66/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4744
# Epoch 67/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.3964
# Epoch 68/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.3689
# Epoch 69/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.3187
# Epoch 70/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.3274
# Epoch 71/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4098
# Epoch 72/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5044
# Epoch 73/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.3111
# Epoch 74/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5419
# Epoch 75/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.2674
# Epoch 76/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.2339
# Epoch 77/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.2636
# Epoch 78/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.3876
# Epoch 79/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.2380
# Epoch 80/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.2038
# Epoch 81/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4599
# Epoch 82/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5542
# Epoch 83/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4086
# Epoch 84/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.2882
# Epoch 85/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.2824
# Epoch 86/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.2994
# Epoch 87/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.2743
# Epoch 88/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.2955
# Epoch 89/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.6353
# Epoch 90/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.3725
# Epoch 91/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.6142
# Epoch 92/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4364
# Epoch 93/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4149
# Epoch 94/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.3700
# Epoch 95/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.1767
# Epoch 96/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.3677
# Epoch 97/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.2138
# Epoch 98/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.1603
# Epoch 99/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.2344
# Epoch 100/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.2641
# Epoch 1/100
# 38/38 [==============================] - 1s 2ms/step - loss: 96.7549
# Epoch 2/100
# 38/38 [==============================] - 0s 2ms/step - loss: 6.1857
# Epoch 3/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.2116
# Epoch 4/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.1611
# Epoch 5/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.2563
# Epoch 6/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.2260
# Epoch 7/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.1456
# Epoch 8/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.1883
# Epoch 9/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.1974
# Epoch 10/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.1772
# Epoch 11/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.1662
# Epoch 12/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.1690
# Epoch 13/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.1795
# Epoch 14/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.1534
# Epoch 15/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.1906
# Epoch 16/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.1806
# Epoch 17/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.1834
# Epoch 18/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.1663
# Epoch 19/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.1791
# Epoch 20/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.2303
# Epoch 21/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.1621
# Epoch 22/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.2508
# Epoch 23/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.1568
# Epoch 24/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.2427
# Epoch 25/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.2206
# Epoch 26/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.2972
# Epoch 27/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.3027
# Epoch 28/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.4440
# Epoch 29/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.2349
# Epoch 30/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.3572
# Epoch 31/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.3447
# Epoch 32/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.3410
# Epoch 33/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.2466
# Epoch 34/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.3568
# Epoch 35/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.2708
# Epoch 36/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.3775
# Epoch 37/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.1863
# Epoch 38/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.1943
# Epoch 39/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.2324
# Epoch 40/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.1970
# Epoch 41/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.2527
# Epoch 42/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.2143
# Epoch 43/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.3132
# Epoch 44/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.1950
# Epoch 45/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.2603
# Epoch 46/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.3121
# Epoch 47/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.1402
# Epoch 48/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.2303
# Epoch 49/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.1941
# Epoch 50/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.2026
# Epoch 51/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.1867
# Epoch 52/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.6046
# Epoch 53/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.5028
# Epoch 54/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.3586
# Epoch 55/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.4069
# Epoch 56/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.3779
# Epoch 57/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.1705
# Epoch 58/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.3693
# Epoch 59/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.4990
# Epoch 60/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.2451
# Epoch 61/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.2386
# Epoch 62/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.2804
# Epoch 63/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.2609
# Epoch 64/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.3880
# Epoch 65/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.4819
# Epoch 66/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.2879
# Epoch 67/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.5368
# Epoch 68/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.2244
# Epoch 69/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.2871
# Epoch 70/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.1730
# Epoch 71/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.2755
# Epoch 72/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.2437
# Epoch 73/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.1957
# Epoch 74/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.1975
# Epoch 75/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.3326
# Epoch 76/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.1991
# Epoch 77/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.3716
# Epoch 78/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.3044
# Epoch 79/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.2712
# Epoch 80/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.4065
# Epoch 81/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.2664
# Epoch 82/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.2316
# Epoch 83/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.3335
# Epoch 84/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.5036
# Epoch 85/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.2704
# Epoch 86/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.4811
# Epoch 87/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.3352
# Epoch 88/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.4377
# Epoch 89/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.3383
# Epoch 90/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.3095
# Epoch 91/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.2297
# Epoch 92/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.2878
# Epoch 93/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.5260
# Epoch 94/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.3103
# Epoch 95/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.3674
# Epoch 96/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.3027
# Epoch 97/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.2790
# Epoch 98/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.3628
# Epoch 99/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.2037
# Epoch 100/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.7663
# 1/1 [==============================] - 0s 187ms/step
# 1/1 [==============================] - 0s 157ms/step
# LSTM - Actual Vibration on the 11th day:
#  [[    1.69    12.06 -1028.63]
#  [   -7.66    14.37 -1028.32]
#  [   -1.13    10.25 -1028.11]
#  ...
#  [   -1.66     6.28 -1028.14]
#  [   -1.98     9.66 -1022.77]
#  [   -1.86    34.75 -1019.18]]
# LSTM - Predicted Vibration on the 11th day:
#  [  -23.047039    26.815044 -1028.8029  ]
# LSTM - Vibration Error for the 11th day:
#  [[24.73703903 14.7550444   0.17285645]
#  [15.38703903 12.4450444   0.48285645]
#  [21.91703903 16.5650444   0.69285645]
#  ...
#  [21.38703903 20.5350444   0.66285645]
#  [21.06703903 17.1550444   6.03285645]
#  [21.18703903  7.9349556   9.62285645]]
# LSTM - Mean Vibration Error for the 11th day:
#  [13.21805236  9.00189624  8.25466488]
#
# LSTM - Actual Temperature on the 11th day:
#  0       26.45
# 1       31.60
# 2       28.22
# 3       30.94
# 4       27.73
#         ...
# 1195    30.33
# 1196    26.44
# 1197    25.97
# 1198    25.68
# 1199    28.17
# Name: Temperature, Length: 1200, dtype: float64
# LSTM - Predicted Temperature on the 11th day:
#  28.514349
# LSTM - Temperature Error for the 11th day:
#  0       2.064349
# 1       3.085651
# 2       0.294349
# 3       2.425651
# 4       0.784349
#           ...
# 1195    1.815651
# 1196    2.074349
# 1197    2.544349
# 1198    2.834349
# 1199    0.344349
# Name: Temperature, Length: 1200, dtype: float64
# LSTM - Mean Temperature Error for the 11th day:
#  2.040956030146281

# %%
# GRU

from keras.layers import GRU

# Create GRU models
model_vibration = Sequential()
model_temperature = Sequential()

# Add GRU layers to the models
model_vibration.add(GRU(units=50, activation='relu', input_shape=(X.shape[1], 1)))
model_vibration.add(Dense(units=X.shape[1]))  # Output layer for vibration

model_temperature.add(GRU(units=50, activation='relu', input_shape=(X.shape[1], 1)))
model_temperature.add(Dense(units=1))  # Output layer for temperature

# Compile the models
model_vibration.compile(optimizer='adam', loss='mean_squared_error')
model_temperature.compile(optimizer='adam', loss='mean_squared_error')

# Reshape the input data for GRU
X_gru = np.array(X).reshape(X.shape[0], X.shape[1], 1)

# Train the models
model_vibration.fit(X_gru, y_vibration, epochs=100, batch_size=32)
model_temperature.fit(X_gru, y_temperature, epochs=100, batch_size=32)

# Predict the 11th day values
X_11th_day_gru = np.array(X.iloc[[-1]]).reshape(1, X.shape[1], 1)
vibration_11th_day_prediction_gru = model_vibration.predict(X_11th_day_gru)
temperature_11th_day_prediction_gru = model_temperature.predict(X_11th_day_gru)

actual_vibration_11th_day = df_actual_values[['Vibration_X', 'Vibration_Y', 'Vibration_Z']].values
actual_temperature_11th_day = df_actual_values['Temperature']  # Replace with the actual value

# Calculate errors
vibration_error_gru = np.abs(vibration_11th_day_prediction_gru[0] - actual_vibration_11th_day)
temperature_error_gru = np.abs(temperature_11th_day_prediction_gru[0][0] - actual_temperature_11th_day)


# Calculate mean errors
mean_vibration_error = vibration_error_gru.mean(axis=0)
mean_temperature_error = temperature_error_gru.mean()

# Display results
print("GRU - Actual Vibration on the 11th day:", actual_vibration_11th_day)
print("GRU - Predicted Vibration on the 11th day:", vibration_11th_day_prediction_gru[0])
print("GRU - Vibration Error for the 11th day:", vibration_error_gru)
print("GRU - Mean Vibration Error for the 11th day: \n", mean_vibration_error)

print("\nGRU - Actual Temperature on the 11th day:", actual_temperature_11th_day)
print("GRU - Predicted Temperature on the 11th day:", temperature_11th_day_prediction_gru[0][0])
print("GRU - Temperature Error for the 11th day:", temperature_error_gru)
print("GRU - Mean Temperature Error for the 11th day: \n", mean_temperature_error)
# Out:
# Epoch 1/100
# 38/38 [==============================] - 1s 2ms/step - loss: 280718.5938
# Epoch 2/100
# 38/38 [==============================] - 0s 2ms/step - loss: 164961.2031
# Epoch 3/100
# 38/38 [==============================] - 0s 2ms/step - loss: 59116.2852
# Epoch 4/100
# 38/38 [==============================] - 0s 2ms/step - loss: 1213.1193
# Epoch 5/100
# 38/38 [==============================] - 0s 2ms/step - loss: 225.2176
# Epoch 6/100
# 38/38 [==============================] - 0s 2ms/step - loss: 136.0142
# Epoch 7/100
# 38/38 [==============================] - 0s 2ms/step - loss: 78.9848
# Epoch 8/100
# 38/38 [==============================] - 0s 2ms/step - loss: 50.4790
# Epoch 9/100
# 38/38 [==============================] - 0s 2ms/step - loss: 37.6944
# Epoch 10/100
# 38/38 [==============================] - 0s 2ms/step - loss: 31.4481
# Epoch 11/100
# 38/38 [==============================] - 0s 2ms/step - loss: 26.7871
# Epoch 12/100
# 38/38 [==============================] - 0s 2ms/step - loss: 24.1976
# Epoch 13/100
# 38/38 [==============================] - 0s 2ms/step - loss: 21.9230
# Epoch 14/100
# 38/38 [==============================] - 0s 2ms/step - loss: 20.2387
# Epoch 15/100
# 38/38 [==============================] - 0s 2ms/step - loss: 18.2725
# Epoch 16/100
# 38/38 [==============================] - 0s 2ms/step - loss: 16.5343
# Epoch 17/100
# 38/38 [==============================] - 0s 2ms/step - loss: 14.4289
# Epoch 18/100
# 38/38 [==============================] - 0s 2ms/step - loss: 11.1138
# Epoch 19/100
# 38/38 [==============================] - 0s 2ms/step - loss: 9.3377
# Epoch 20/100
# 38/38 [==============================] - 0s 2ms/step - loss: 6.5285
# Epoch 21/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.7256
# Epoch 22/100
# 38/38 [==============================] - 0s 2ms/step - loss: 4.9842
# Epoch 23/100
# 38/38 [==============================] - 0s 2ms/step - loss: 4.7967
# Epoch 24/100
# 38/38 [==============================] - 0s 2ms/step - loss: 4.4531
# Epoch 25/100
# 38/38 [==============================] - 0s 2ms/step - loss: 3.8351
# Epoch 26/100
# 38/38 [==============================] - 0s 2ms/step - loss: 3.6341
# Epoch 27/100
# 38/38 [==============================] - 0s 2ms/step - loss: 3.3730
# Epoch 28/100
# 38/38 [==============================] - 0s 2ms/step - loss: 2.7273
# Epoch 29/100
# 38/38 [==============================] - 0s 2ms/step - loss: 2.4304
# Epoch 30/100
# 38/38 [==============================] - 0s 2ms/step - loss: 2.2458
# Epoch 31/100
# 38/38 [==============================] - 0s 2ms/step - loss: 2.5027
# Epoch 32/100
# 38/38 [==============================] - 0s 2ms/step - loss: 1.8864
# Epoch 33/100
# 38/38 [==============================] - 0s 2ms/step - loss: 2.0180
# Epoch 34/100
# 38/38 [==============================] - 0s 2ms/step - loss: 1.7587
# Epoch 35/100
# 38/38 [==============================] - 0s 2ms/step - loss: 1.7201
# Epoch 36/100
# 38/38 [==============================] - 0s 2ms/step - loss: 1.6465
# Epoch 37/100
# 38/38 [==============================] - 0s 2ms/step - loss: 1.8481
# Epoch 38/100
# 38/38 [==============================] - 0s 2ms/step - loss: 1.6227
# Epoch 39/100
# 38/38 [==============================] - 0s 2ms/step - loss: 1.5046
# Epoch 40/100
# 38/38 [==============================] - 0s 2ms/step - loss: 1.1003
# Epoch 41/100
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0531
# Epoch 42/100
# 38/38 [==============================] - 0s 2ms/step - loss: 1.1345
# Epoch 43/100
# 38/38 [==============================] - 0s 2ms/step - loss: 1.2043
# Epoch 44/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.9566
# Epoch 45/100
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0507
# Epoch 46/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.8394
# Epoch 47/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.9481
# Epoch 48/100
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0640
# Epoch 49/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.9938
# Epoch 50/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.9197
# Epoch 51/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.9095
# Epoch 52/100
# 38/38 [==============================] - 0s 2ms/step - loss: 1.2336
# Epoch 53/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.7988
# Epoch 54/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.6711
# Epoch 55/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.7762
# Epoch 56/100
# 38/38 [==============================] - 0s 2ms/step - loss: 1.5188
# Epoch 57/100
# 38/38 [==============================] - 0s 2ms/step - loss: 1.7158
# Epoch 58/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.8714
# Epoch 59/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.6098
# Epoch 60/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.6605
# Epoch 61/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5756
# Epoch 62/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5318
# Epoch 63/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5443
# Epoch 64/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5902
# Epoch 65/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.8319
# Epoch 66/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5483
# Epoch 67/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.6855
# Epoch 68/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5422
# Epoch 69/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5783
# Epoch 70/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5271
# Epoch 71/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5910
# Epoch 72/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.6960
# Epoch 73/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5256
# Epoch 74/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5083
# Epoch 75/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4058
# Epoch 76/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4253
# Epoch 77/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.6698
# Epoch 78/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.3975
# Epoch 79/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4143
# Epoch 80/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4205
# Epoch 81/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.3954
# Epoch 82/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.3575
# Epoch 83/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4133
# Epoch 84/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.3486
# Epoch 85/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.2693
# Epoch 86/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.2476
# Epoch 87/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.2912
# Epoch 88/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4253
# Epoch 89/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5935
# Epoch 90/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4132
# Epoch 91/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.2208
# Epoch 92/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.3291
# Epoch 93/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.3285
# Epoch 94/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4199
# Epoch 95/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.3001
# Epoch 96/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4049
# Epoch 97/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.1637
# Epoch 98/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.1367
# Epoch 99/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.2399
# Epoch 100/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4621
# Epoch 1/100
# 38/38 [==============================] - 2s 3ms/step - loss: 196.3078
# Epoch 2/100
# 38/38 [==============================] - 0s 3ms/step - loss: 8.1411
# Epoch 3/100
# 38/38 [==============================] - 0s 3ms/step - loss: 5.3534
# Epoch 4/100
# 38/38 [==============================] - 0s 3ms/step - loss: 5.4416
# Epoch 5/100
# 38/38 [==============================] - 0s 3ms/step - loss: 5.3174
# Epoch 6/100
# 38/38 [==============================] - 0s 3ms/step - loss: 5.2887
# Epoch 7/100
# 38/38 [==============================] - 0s 3ms/step - loss: 5.2450
# Epoch 8/100
# 38/38 [==============================] - 0s 3ms/step - loss: 5.1921
# Epoch 9/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.2721
# Epoch 10/100
# 38/38 [==============================] - 0s 3ms/step - loss: 5.2269
# Epoch 11/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.2048
# Epoch 12/100
# 38/38 [==============================] - 0s 3ms/step - loss: 5.2154
# Epoch 13/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.1521
# Epoch 14/100
# 38/38 [==============================] - 0s 3ms/step - loss: 5.1890
# Epoch 15/100
# 38/38 [==============================] - 0s 3ms/step - loss: 5.1682
# Epoch 16/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.2057
# Epoch 17/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.3172
# Epoch 18/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.3412
# Epoch 19/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.3221
# Epoch 20/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.1801
# Epoch 21/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.1664
# Epoch 22/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.1707
# Epoch 23/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.1915
# Epoch 24/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.2354
# Epoch 25/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.3984
# Epoch 26/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.2508
# Epoch 27/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.1916
# Epoch 28/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.2465
# Epoch 29/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.2461
# Epoch 30/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.1595
# Epoch 31/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.2740
# Epoch 32/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.3281
# Epoch 33/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.4152
# Epoch 34/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.3395
# Epoch 35/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.4342
# Epoch 36/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.4584
# Epoch 37/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.3230
# Epoch 38/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.2266
# Epoch 39/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.2094
# Epoch 40/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.1789
# Epoch 41/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.1822
# Epoch 42/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.3065
# Epoch 43/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.5975
# Epoch 44/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.3303
# Epoch 45/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.3825
# Epoch 46/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.1852
# Epoch 47/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.5165
# Epoch 48/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.2162
# Epoch 49/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.2185
# Epoch 50/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.5213
# Epoch 51/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.1834
# Epoch 52/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.2113
# Epoch 53/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.3183
# Epoch 54/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.3428
# Epoch 55/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.2673
# Epoch 56/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.2932
# Epoch 57/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.2699
# Epoch 58/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.2853
# Epoch 59/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.2149
# Epoch 60/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.5218
# Epoch 61/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.5156
# Epoch 62/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.3666
# Epoch 63/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.2677
# Epoch 64/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.1670
# Epoch 65/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.3536
# Epoch 66/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.2880
# Epoch 67/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.2774
# Epoch 68/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.2231
# Epoch 69/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.2818
# Epoch 70/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.3434
# Epoch 71/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.2553
# Epoch 72/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.5149
# Epoch 73/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.2919
# Epoch 74/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.3763
# Epoch 75/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.4737
# Epoch 76/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.5130
# Epoch 77/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.1687
# Epoch 78/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.2870
# Epoch 79/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.8899
# Epoch 80/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.3131
# Epoch 81/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.3345
# Epoch 82/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.5558
# Epoch 83/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.4849
# Epoch 84/100
# 38/38 [==============================] - 0s 2ms/step - loss: 6.1360
# Epoch 85/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.2502
# Epoch 86/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.1747
# Epoch 87/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.2431
# Epoch 88/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.2443
# Epoch 89/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.2101
# Epoch 90/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.5749
# Epoch 91/100
# 38/38 [==============================] - 0s 2ms/step - loss: 6.0460
# Epoch 92/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.5304
# Epoch 93/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.4696
# Epoch 94/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.2936
# Epoch 95/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.8016
# Epoch 96/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.5944
# Epoch 97/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.4819
# Epoch 98/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.4277
# Epoch 99/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.5334
# Epoch 100/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.4281
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 115ms/step
# GRU - Actual Vibration on the 11th day: [[    1.69    12.06 -1028.63]
#  [   -7.66    14.37 -1028.32]
#  [   -1.13    10.25 -1028.11]
#  ...
#  [   -1.66     6.28 -1028.14]
#  [   -1.98     9.66 -1022.77]
#  [   -1.86    34.75 -1019.18]]
# GRU - Predicted Vibration on the 11th day: [  -23.179733    26.48685  -1029.1292  ]
# GRU - Vibration Error for the 11th day: [[24.86973328 14.42685074  0.49915039]
#  [15.51973328 12.11685074  0.80915039]
#  [22.04973328 16.23685074  1.01915039]
#  ...
#  [21.51973328 20.20685074  0.98915039]
#  [21.19973328 16.82685074  6.35915039]
#  [21.31973328  8.26314926  9.94915039]]
# GRU - Mean Vibration Error for the 11th day:
#  [13.33409862  8.84911092  8.54280186]
#
# GRU - Actual Temperature on the 11th day: 0       26.45
# 1       31.60
# 2       28.22
# 3       30.94
# 4       27.73
#         ...
# 1195    30.33
# 1196    26.44
# 1197    25.97
# 1198    25.68
# 1199    28.17
# Name: Temperature, Length: 1200, dtype: float64
# GRU - Predicted Temperature on the 11th day: 28.937397
# GRU - Temperature Error for the 11th day: 0       2.487397
# 1       2.662603
# 2       0.717397
# 3       2.002603
# 4       1.207397
#           ...
# 1195    1.392603
# 1196    2.497397
# 1197    2.967397
# 1198    3.257397
# 1199    0.767397
# Name: Temperature, Length: 1200, dtype: float64
# GRU - Mean Temperature Error for the 11th day:
#  2.018061985015869

# %%
from keras.models import Sequential
from keras.layers import Bidirectional, LSTM, Dense

# Create BiLSTM models
model_vibration_bilstm = Sequential()
model_temperature_bilstm = Sequential()

# Add BiLSTM layers to the models
model_vibration_bilstm.add(Bidirectional(LSTM(units=50, activation='relu'), input_shape=(X.shape[1], 1)))
model_vibration_bilstm.add(Dense(units=X.shape[1]))  # Output layer for vibration

model_temperature_bilstm.add(Bidirectional(LSTM(units=50, activation='relu'), input_shape=(X.shape[1], 1)))
model_temperature_bilstm.add(Dense(units=1))  # Output layer for temperature

# Compile the models
model_vibration_bilstm.compile(optimizer='adam', loss='mean_squared_error')
model_temperature_bilstm.compile(optimizer='adam', loss='mean_squared_error')

# Reshape the input data for BiLSTM
X_bilstm = np.array(X).reshape(X.shape[0], X.shape[1], 1)

# Train the models
model_vibration_bilstm.fit(X_bilstm, y_vibration, epochs=100, batch_size=32)
model_temperature_bilstm.fit(X_bilstm, y_temperature, epochs=100, batch_size=32)

# Predict the 11th day values
X_11th_day_bilstm = np.array(X.iloc[[-1]]).reshape(1, X.shape[1], 1)
vibration_11th_day_prediction_bilstm = model_vibration_bilstm.predict(X_11th_day_bilstm)
temperature_11th_day_prediction_bilstm = model_temperature_bilstm.predict(X_11th_day_bilstm)

# Actual values for the 11th day
actual_vibration_11th_day = df_actual_values[['Vibration_X', 'Vibration_Y', 'Vibration_Z']].values
actual_temperature_11th_day = df_actual_values['Temperature']  # Replace with the actual value

# Calculate errors
vibration_error_bilstm = np.abs(vibration_11th_day_prediction_bilstm[0] - actual_vibration_11th_day)
temperature_error_bilstm = np.abs(temperature_11th_day_prediction_bilstm[0][0] - actual_temperature_11th_day)


# Calculate mean errors
mean_vibration_error = vibration_error_bilstm.mean(axis=0)
mean_temperature_error = temperature_error_bilstm.mean()

# Display results
print("BiLSTM - Actual Vibration on the 11th day:", actual_vibration_11th_day)
print("BiLSTM - Predicted Vibration on the 11th day:", vibration_11th_day_prediction_bilstm[0])
print("BiLSTM - Vibration Error for the 11th day:", vibration_error_bilstm)
print("BiLSTM - Mean Vibration Error for the 11th day: \n", mean_vibration_error)

print("\nBiLSTM - Actual Temperature on the 11th day:", actual_temperature_11th_day)
print("BiLSTM - Predicted Temperature on the 11th day:", temperature_11th_day_prediction_bilstm[0][0])
print("BiLSTM - Temperature Error for the 11th day:", temperature_error_bilstm)
print("BiLSTM - Mean Temperature Error for the 11th day: \n", mean_temperature_error)
# Out:
# Epoch 1/100
# 38/38 [==============================] - 2s 2ms/step - loss: 223300.9375
# Epoch 2/100
# 38/38 [==============================] - 0s 2ms/step - loss: 42537.7227
# Epoch 3/100
# 38/38 [==============================] - 0s 2ms/step - loss: 637.8463
# Epoch 4/100
# 38/38 [==============================] - 0s 2ms/step - loss: 66.8313
# Epoch 5/100
# 38/38 [==============================] - 0s 2ms/step - loss: 58.1483
# Epoch 6/100
# 38/38 [==============================] - 0s 2ms/step - loss: 56.4015
# Epoch 7/100
# 38/38 [==============================] - 0s 2ms/step - loss: 54.4590
# Epoch 8/100
# 38/38 [==============================] - 0s 3ms/step - loss: 52.5936
# Epoch 9/100
# 38/38 [==============================] - 0s 2ms/step - loss: 50.4755
# Epoch 10/100
# 38/38 [==============================] - 0s 2ms/step - loss: 49.0744
# Epoch 11/100
# 38/38 [==============================] - 0s 3ms/step - loss: 46.8658
# Epoch 12/100
# 38/38 [==============================] - 0s 2ms/step - loss: 45.2967
# Epoch 13/100
# 38/38 [==============================] - 0s 5ms/step - loss: 44.0138
# Epoch 14/100
# 38/38 [==============================] - 0s 5ms/step - loss: 42.5248
# Epoch 15/100
# 38/38 [==============================] - 0s 4ms/step - loss: 40.7450
# Epoch 16/100
# 38/38 [==============================] - 0s 6ms/step - loss: 38.8254
# Epoch 17/100
# 38/38 [==============================] - 0s 5ms/step - loss: 37.5849
# Epoch 18/100
# 38/38 [==============================] - 0s 5ms/step - loss: 35.8488
# Epoch 19/100
# 38/38 [==============================] - 0s 5ms/step - loss: 34.3984
# Epoch 20/100
# 38/38 [==============================] - 0s 5ms/step - loss: 32.8612
# Epoch 21/100
# 38/38 [==============================] - 0s 5ms/step - loss: 30.4287
# Epoch 22/100
# 38/38 [==============================] - 0s 7ms/step - loss: 28.5266
# Epoch 23/100
# 38/38 [==============================] - 0s 6ms/step - loss: 26.5219
# Epoch 24/100
# 38/38 [==============================] - 0s 5ms/step - loss: 24.4881
# Epoch 25/100
# 38/38 [==============================] - 0s 4ms/step - loss: 22.3173
# Epoch 26/100
# 38/38 [==============================] - 0s 5ms/step - loss: 19.6695
# Epoch 27/100
# 38/38 [==============================] - 0s 5ms/step - loss: 16.4184
# Epoch 28/100
# 38/38 [==============================] - 0s 4ms/step - loss: 23.6190
# Epoch 29/100
# 38/38 [==============================] - 0s 4ms/step - loss: 10.4624
# Epoch 30/100
# 38/38 [==============================] - 0s 4ms/step - loss: 8.0245
# Epoch 31/100
# 38/38 [==============================] - 0s 4ms/step - loss: 6.4130
# Epoch 32/100
# 38/38 [==============================] - 0s 3ms/step - loss: 4.9006
# Epoch 33/100
# 38/38 [==============================] - 0s 3ms/step - loss: 3.7551
# Epoch 34/100
# 38/38 [==============================] - 0s 3ms/step - loss: 2.9160
# Epoch 35/100
# 38/38 [==============================] - 0s 2ms/step - loss: 2.3932
# Epoch 36/100
# 38/38 [==============================] - 0s 2ms/step - loss: 1.7534
# Epoch 37/100
# 38/38 [==============================] - 0s 2ms/step - loss: 1.3890
# Epoch 38/100
# 38/38 [==============================] - 0s 2ms/step - loss: 1.1523
# Epoch 39/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.9237
# Epoch 40/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.7712
# Epoch 41/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.6792
# Epoch 42/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5779
# Epoch 43/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5030
# Epoch 44/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.4011
# Epoch 45/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.3748
# Epoch 46/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.3703
# Epoch 47/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.3108
# Epoch 48/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.2718
# Epoch 49/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.2103
# Epoch 50/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.1750
# Epoch 51/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.1864
# Epoch 52/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.1629
# Epoch 53/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.1275
# Epoch 54/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.1003
# Epoch 55/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.0815
# Epoch 56/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0724
# Epoch 57/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0746
# Epoch 58/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0721
# Epoch 59/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0692
# Epoch 60/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0594
# Epoch 61/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0543
# Epoch 62/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0535
# Epoch 63/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0601
# Epoch 64/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0484
# Epoch 65/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.0478
# Epoch 66/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0459
# Epoch 67/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.0400
# Epoch 68/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0480
# Epoch 69/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0450
# Epoch 70/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0475
# Epoch 71/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0376
# Epoch 72/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.0343
# Epoch 73/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.0368
# Epoch 74/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.0380
# Epoch 75/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.0331
# Epoch 76/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.0313
# Epoch 77/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.0385
# Epoch 78/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.0374
# Epoch 79/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.0311
# Epoch 80/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.0303
# Epoch 81/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.0315
# Epoch 82/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.0458
# Epoch 83/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.0282
# Epoch 84/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.0263
# Epoch 85/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.0346
# Epoch 86/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.0319
# Epoch 87/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.0334
# Epoch 88/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.0232
# Epoch 89/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.0269
# Epoch 90/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.0224
# Epoch 91/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.0212
# Epoch 92/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0229
# Epoch 93/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0232
# Epoch 94/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.0250
# Epoch 95/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0213
# Epoch 96/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.0206
# Epoch 97/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.0216
# Epoch 98/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.0183
# Epoch 99/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0207
# Epoch 100/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0283
# Epoch 1/100
# 38/38 [==============================] - 2s 3ms/step - loss: 10.9104
# Epoch 2/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.3219
# Epoch 3/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.2732
# Epoch 4/100
# 38/38 [==============================] - 0s 3ms/step - loss: 5.3356
# Epoch 5/100
# 38/38 [==============================] - 0s 3ms/step - loss: 5.1853
# Epoch 6/100
# 38/38 [==============================] - 0s 3ms/step - loss: 5.4860
# Epoch 7/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.3551
# Epoch 8/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.2129
# Epoch 9/100
# 38/38 [==============================] - 0s 3ms/step - loss: 5.2378
# Epoch 10/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.2132
# Epoch 11/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.4283
# Epoch 12/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.4237
# Epoch 13/100
# 38/38 [==============================] - 0s 3ms/step - loss: 5.4296
# Epoch 14/100
# 38/38 [==============================] - 0s 3ms/step - loss: 5.1949
# Epoch 15/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.3346
# Epoch 16/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.4476
# Epoch 17/100
# 38/38 [==============================] - 0s 3ms/step - loss: 5.2837
# Epoch 18/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.1768
# Epoch 19/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.2926
# Epoch 20/100
# 38/38 [==============================] - 0s 3ms/step - loss: 5.4968
# Epoch 21/100
# 38/38 [==============================] - 0s 3ms/step - loss: 5.3247
# Epoch 22/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.2400
# Epoch 23/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.4166
# Epoch 24/100
# 38/38 [==============================] - 0s 3ms/step - loss: 5.2622
# Epoch 25/100
# 38/38 [==============================] - 0s 3ms/step - loss: 5.3987
# Epoch 26/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.4859
# Epoch 27/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.2788
# Epoch 28/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.4777
# Epoch 29/100
# 38/38 [==============================] - 0s 3ms/step - loss: 5.3015
# Epoch 30/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.4867
# Epoch 31/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.2423
# Epoch 32/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.2720
# Epoch 33/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.7108
# Epoch 34/100
# 38/38 [==============================] - 0s 3ms/step - loss: 5.3157
# Epoch 35/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.2510
# Epoch 36/100
# 38/38 [==============================] - 0s 3ms/step - loss: 5.2372
# Epoch 37/100
# 38/38 [==============================] - 0s 3ms/step - loss: 5.2706
# Epoch 38/100
# 38/38 [==============================] - 0s 3ms/step - loss: 5.6175
# Epoch 39/100
# 38/38 [==============================] - 0s 3ms/step - loss: 5.2148
# Epoch 40/100
# 38/38 [==============================] - 0s 3ms/step - loss: 5.2383
# Epoch 41/100
# 38/38 [==============================] - 0s 3ms/step - loss: 5.1984
# Epoch 42/100
# 38/38 [==============================] - 0s 3ms/step - loss: 5.1969
# Epoch 43/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.5328
# Epoch 44/100
# 38/38 [==============================] - 0s 3ms/step - loss: 5.2994
# Epoch 45/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.3324
# Epoch 46/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.4187
# Epoch 47/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.2836
# Epoch 48/100
# 38/38 [==============================] - 0s 3ms/step - loss: 5.3331
# Epoch 49/100
# 38/38 [==============================] - 0s 3ms/step - loss: 5.2984
# Epoch 50/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.2701
# Epoch 51/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.3926
# Epoch 52/100
# 38/38 [==============================] - 0s 3ms/step - loss: 5.3205
# Epoch 53/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.2172
# Epoch 54/100
# 38/38 [==============================] - 0s 3ms/step - loss: 5.2092
# Epoch 55/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.3750
# Epoch 56/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.1870
# Epoch 57/100
# 38/38 [==============================] - 0s 3ms/step - loss: 5.4182
# Epoch 58/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.2941
# Epoch 59/100
# 38/38 [==============================] - 0s 3ms/step - loss: 5.3526
# Epoch 60/100
# 38/38 [==============================] - 0s 3ms/step - loss: 5.6828
# Epoch 61/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.2507
# Epoch 62/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.3628
# Epoch 63/100
# 38/38 [==============================] - 0s 3ms/step - loss: 5.3543
# Epoch 64/100
# 38/38 [==============================] - 0s 3ms/step - loss: 5.2110
# Epoch 65/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.3209
# Epoch 66/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.3556
# Epoch 67/100
# 38/38 [==============================] - 0s 3ms/step - loss: 5.2902
# Epoch 68/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.4264
# Epoch 69/100
# 38/38 [==============================] - 0s 3ms/step - loss: 5.3965
# Epoch 70/100
# 38/38 [==============================] - 0s 3ms/step - loss: 5.3820
# Epoch 71/100
# 38/38 [==============================] - 0s 3ms/step - loss: 5.3141
# Epoch 72/100
# 38/38 [==============================] - 0s 3ms/step - loss: 5.2114
# Epoch 73/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.7860
# Epoch 74/100
# 38/38 [==============================] - 0s 3ms/step - loss: 5.4344
# Epoch 75/100
# 38/38 [==============================] - 0s 4ms/step - loss: 5.3094
# Epoch 76/100
# 38/38 [==============================] - 0s 4ms/step - loss: 5.1969
# Epoch 77/100
# 38/38 [==============================] - 0s 4ms/step - loss: 5.1207
# Epoch 78/100
# 38/38 [==============================] - 0s 4ms/step - loss: 5.4455
# Epoch 79/100
# 38/38 [==============================] - 0s 4ms/step - loss: 5.3964
# Epoch 80/100
# 38/38 [==============================] - 0s 4ms/step - loss: 5.1397
# Epoch 81/100
# 38/38 [==============================] - 0s 4ms/step - loss: 5.2175
# Epoch 82/100
# 38/38 [==============================] - 0s 4ms/step - loss: 5.2727
# Epoch 83/100
# 38/38 [==============================] - 0s 4ms/step - loss: 5.1593
# Epoch 84/100
# 38/38 [==============================] - 0s 4ms/step - loss: 5.3558
# Epoch 85/100
# 38/38 [==============================] - 0s 4ms/step - loss: 5.3630
# Epoch 86/100
# 38/38 [==============================] - 0s 4ms/step - loss: 5.1492
# Epoch 87/100
# 38/38 [==============================] - 0s 4ms/step - loss: 5.1733
# Epoch 88/100
# 38/38 [==============================] - 0s 4ms/step - loss: 5.3234
# Epoch 89/100
# 38/38 [==============================] - 0s 3ms/step - loss: 5.3512
# Epoch 90/100
# 38/38 [==============================] - 0s 4ms/step - loss: 5.3711
# Epoch 91/100
# 38/38 [==============================] - 0s 4ms/step - loss: 5.4066
# Epoch 92/100
# 38/38 [==============================] - 0s 4ms/step - loss: 5.3108
# Epoch 93/100
# 38/38 [==============================] - 0s 3ms/step - loss: 5.2365
# Epoch 94/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.2059
# Epoch 95/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.1527
# Epoch 96/100
# 38/38 [==============================] - 0s 3ms/step - loss: 5.1613
# Epoch 97/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.3746
# Epoch 98/100
# 38/38 [==============================] - 0s 3ms/step - loss: 5.2840
# Epoch 99/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.1155
# Epoch 100/100
# 38/38 [==============================] - 0s 3ms/step - loss: 5.1598
# 1/1 [==============================] - 0s 195ms/step
# 1/1 [==============================] - 1s 516ms/step
# BiLSTM - Actual Vibration on the 11th day: [[    1.69    12.06 -1028.63]
#  [   -7.66    14.37 -1028.32]
#  [   -1.13    10.25 -1028.11]
#  ...
#  [   -1.66     6.28 -1028.14]
#  [   -1.98     9.66 -1022.77]
#  [   -1.86    34.75 -1019.18]]
# BiLSTM - Predicted Vibration on the 11th day: [  -23.292013    26.701756 -1028.9783  ]
# BiLSTM - Vibration Error for the 11th day: [[24.98201317 14.64175552  0.34827148]
#  [15.63201317 12.33175552  0.65827148]
#  [22.16201317 16.45175552  0.86827148]
#  ...
#  [21.63201317 20.42175552  0.83827148]
#  [21.31201317 17.04175552  6.20827148]
#  [21.43201317  8.04824448  9.79827148]]
# BiLSTM - Mean Vibration Error for the 11th day:
#  [13.43330503  8.94817802  8.40784814]
#
# BiLSTM - Actual Temperature on the 11th day: 0       26.45
# 1       31.60
# 2       28.22
# 3       30.94
# 4       27.73
#         ...
# 1195    30.33
# 1196    26.44
# 1197    25.97
# 1198    25.68
# 1199    28.17
# Name: Temperature, Length: 1200, dtype: float64
# BiLSTM - Predicted Temperature on the 11th day: 29.178932
# BiLSTM - Temperature Error for the 11th day: 0       2.728932
# 1       2.421068
# 2       0.958932
# 3       1.761068
# 4       1.448932
#           ...
# 1195    1.151068
# 1196    2.738932
# 1197    3.208932
# 1198    3.498932
# 1199    1.008932
# Name: Temperature, Length: 1200, dtype: float64
# BiLSTM - Mean Temperature Error for the 11th day:
#  2.025346044413249

# %%
from keras.models import Sequential
from keras.layers import LSTM, Dense

# Create Stacked LSTM models
model_vibration = Sequential()
model_temperature = Sequential()

# Add Stacked LSTM layers to the models
model_vibration.add(LSTM(units=50, activation='relu', return_sequences=True, input_shape=(X.shape[1], 1)))
model_vibration.add(LSTM(units=50, activation='relu'))
model_vibration.add(Dense(units=X.shape[1]))  # Output layer for vibration

model_temperature.add(LSTM(units=50, activation='relu', return_sequences=True, input_shape=(X.shape[1], 1)))
model_temperature.add(LSTM(units=50, activation='relu'))
model_temperature.add(Dense(units=1))  # Output layer for temperature

# Compile the models
model_vibration.compile(optimizer='adam', loss='mean_squared_error')
model_temperature.compile(optimizer='adam', loss='mean_squared_error')

# Reshape the input data for Stacked LSTM
X_stacked_lstm = np.array(X).reshape(X.shape[0], X.shape[1], 1)

# Train the models
model_vibration.fit(X_stacked_lstm, y_vibration, epochs=100, batch_size=32)
model_temperature.fit(X_stacked_lstm, y_temperature, epochs=100, batch_size=32)

# Predict the 11th day values
X_11th_day_stacked_lstm = np.array(X.iloc[[-1]]).reshape(1, X.shape[1], 1)
vibration_11th_day_prediction_stacked_lstm = model_vibration.predict(X_11th_day_stacked_lstm)
temperature_11th_day_prediction_stacked_lstm = model_temperature.predict(X_11th_day_stacked_lstm)

# Actual values for the 11th day
actual_vibration_11th_day = df_actual_values[['Vibration_X', 'Vibration_Y', 'Vibration_Z']].values
actual_temperature_11th_day = df_actual_values['Temperature']  # Replace with the actual value

# Calculate errors
vibration_error_stacked_lstm = np.abs(vibration_11th_day_prediction_stacked_lstm[0] - actual_vibration_11th_day)
temperature_error_stacked_lstm = np.abs(temperature_11th_day_prediction_stacked_lstm[0][0] - actual_temperature_11th_day)

mean_vibration_error = vibration_error_stacked_lstm.mean(axis=0)
mean_temperature_error = temperature_error_stacked_lstm.mean()

# Display results
print("Stacked LSTM - Actual Vibration on the 11th day:", actual_vibration_11th_day)
print("Stacked LSTM - Predicted Vibration on the 11th day:", vibration_11th_day_prediction_stacked_lstm[0])
print("Stacked LSTM - Vibration Error for the 11th day:", vibration_error_stacked_lstm)
print("Stacked LSTM - Mean Vibration Error for the 11th day: \n", mean_vibration_error)

print("\nStacked LSTM - Actual Temperature on the 11th day:", actual_temperature_11th_day)
print("Stacked LSTM - Predicted Temperature on the 11th day:", temperature_11th_day_prediction_stacked_lstm[0][0])
print("Stacked LSTM - Temperature Error for the 11th day:", temperature_error_stacked_lstm)
print("Stacked LSTM - Mean Temperature Error for the 11th day: \n", mean_temperature_error)
# Out:
# Epoch 1/100
# 38/38 [==============================] - 2s 3ms/step - loss: 339654.1562
# Epoch 2/100
# 38/38 [==============================] - 0s 3ms/step - loss: 218897.5000
# Epoch 3/100
# 38/38 [==============================] - 0s 3ms/step - loss: 13767.7441
# Epoch 4/100
# 38/38 [==============================] - 0s 3ms/step - loss: 3208.9700
# Epoch 5/100
# 38/38 [==============================] - 0s 3ms/step - loss: 913.7526
# Epoch 6/100
# 38/38 [==============================] - 0s 3ms/step - loss: 253.3135
# Epoch 7/100
# 38/38 [==============================] - 0s 3ms/step - loss: 103.6959
# Epoch 8/100
# 38/38 [==============================] - 0s 3ms/step - loss: 71.9318
# Epoch 9/100
# 38/38 [==============================] - 0s 3ms/step - loss: 42.3399
# Epoch 10/100
# 38/38 [==============================] - 0s 3ms/step - loss: 37.1541
# Epoch 11/100
# 38/38 [==============================] - 0s 4ms/step - loss: 29.1083
# Epoch 12/100
# 38/38 [==============================] - 0s 4ms/step - loss: 37.1277
# Epoch 13/100
# 38/38 [==============================] - 0s 4ms/step - loss: 23.3253
# Epoch 14/100
# 38/38 [==============================] - 0s 4ms/step - loss: 15.4961
# Epoch 15/100
# 38/38 [==============================] - 0s 4ms/step - loss: 15.1814
# Epoch 16/100
# 38/38 [==============================] - 0s 5ms/step - loss: 19.3383
# Epoch 17/100
# 38/38 [==============================] - 0s 4ms/step - loss: 16.7047
# Epoch 18/100
# 38/38 [==============================] - 0s 4ms/step - loss: 13.3279
# Epoch 19/100
# 38/38 [==============================] - 0s 4ms/step - loss: 11.7854
# Epoch 20/100
# 38/38 [==============================] - 0s 4ms/step - loss: 9.3496
# Epoch 21/100
# 38/38 [==============================] - 0s 4ms/step - loss: 10.9289
# Epoch 22/100
# 38/38 [==============================] - 0s 4ms/step - loss: 16.3874
# Epoch 23/100
# 38/38 [==============================] - 0s 4ms/step - loss: 15.1357
# Epoch 24/100
# 38/38 [==============================] - 0s 4ms/step - loss: 6.7752
# Epoch 25/100
# 38/38 [==============================] - 0s 4ms/step - loss: 6.9547
# Epoch 26/100
# 38/38 [==============================] - 0s 4ms/step - loss: 5.9724
# Epoch 27/100
# 38/38 [==============================] - 0s 5ms/step - loss: 7.2577
# Epoch 28/100
# 38/38 [==============================] - 0s 3ms/step - loss: 5.4569
# Epoch 29/100
# 38/38 [==============================] - 0s 3ms/step - loss: 5.6961
# Epoch 30/100
# 38/38 [==============================] - 0s 3ms/step - loss: 9.3211
# Epoch 31/100
# 38/38 [==============================] - 0s 3ms/step - loss: 7.4176
# Epoch 32/100
# 38/38 [==============================] - 0s 3ms/step - loss: 15.1944
# Epoch 33/100
# 38/38 [==============================] - 0s 3ms/step - loss: 4.7576
# Epoch 34/100
# 38/38 [==============================] - 0s 3ms/step - loss: 3.6027
# Epoch 35/100
# 38/38 [==============================] - 0s 3ms/step - loss: 3.1398
# Epoch 36/100
# 38/38 [==============================] - 0s 3ms/step - loss: 4.9906
# Epoch 37/100
# 38/38 [==============================] - 0s 3ms/step - loss: 2.9970
# Epoch 38/100
# 38/38 [==============================] - 0s 3ms/step - loss: 4.1838
# Epoch 39/100
# 38/38 [==============================] - 0s 3ms/step - loss: 3.3992
# Epoch 40/100
# 38/38 [==============================] - 0s 3ms/step - loss: 4.5058
# Epoch 41/100
# 38/38 [==============================] - 0s 3ms/step - loss: 6.4998
# Epoch 42/100
# 38/38 [==============================] - 0s 3ms/step - loss: 9.5001
# Epoch 43/100
# 38/38 [==============================] - 0s 3ms/step - loss: 2.5949
# Epoch 44/100
# 38/38 [==============================] - 0s 3ms/step - loss: 2.8366
# Epoch 45/100
# 38/38 [==============================] - 0s 3ms/step - loss: 2.1944
# Epoch 46/100
# 38/38 [==============================] - 0s 3ms/step - loss: 1.9704
# Epoch 47/100
# 38/38 [==============================] - 0s 3ms/step - loss: 2.0986
# Epoch 48/100
# 38/38 [==============================] - 0s 3ms/step - loss: 1.9601
# Epoch 49/100
# 38/38 [==============================] - 0s 3ms/step - loss: 3.1504
# Epoch 50/100
# 38/38 [==============================] - 0s 3ms/step - loss: 1.8256
# Epoch 51/100
# 38/38 [==============================] - 0s 3ms/step - loss: 2.6168
# Epoch 52/100
# 38/38 [==============================] - 0s 3ms/step - loss: 4.5669
# Epoch 53/100
# 38/38 [==============================] - 0s 3ms/step - loss: 1.6419
# Epoch 54/100
# 38/38 [==============================] - 0s 3ms/step - loss: 1.6138
# Epoch 55/100
# 38/38 [==============================] - 0s 3ms/step - loss: 1.9533
# Epoch 56/100
# 38/38 [==============================] - 0s 3ms/step - loss: 6.6099
# Epoch 57/100
# 38/38 [==============================] - 0s 3ms/step - loss: 3.1472
# Epoch 58/100
# 38/38 [==============================] - 0s 3ms/step - loss: 1.2792
# Epoch 59/100
# 38/38 [==============================] - 0s 3ms/step - loss: 1.3148
# Epoch 60/100
# 38/38 [==============================] - 0s 3ms/step - loss: 2.3009
# Epoch 61/100
# 38/38 [==============================] - 0s 3ms/step - loss: 3.6005
# Epoch 62/100
# 38/38 [==============================] - 0s 3ms/step - loss: 2.3718
# Epoch 63/100
# 38/38 [==============================] - 0s 3ms/step - loss: 2.4465
# Epoch 64/100
# 38/38 [==============================] - 0s 3ms/step - loss: 1.5436
# Epoch 65/100
# 38/38 [==============================] - 0s 3ms/step - loss: 1.6745
# Epoch 66/100
# 38/38 [==============================] - 0s 3ms/step - loss: 9.8011
# Epoch 67/100
# 38/38 [==============================] - 0s 3ms/step - loss: 4.1635
# Epoch 68/100
# 38/38 [==============================] - 0s 3ms/step - loss: 3.3343
# Epoch 69/100
# 38/38 [==============================] - 0s 3ms/step - loss: 2.4482
# Epoch 70/100
# 38/38 [==============================] - 0s 3ms/step - loss: 1.4922
# Epoch 71/100
# 38/38 [==============================] - 0s 3ms/step - loss: 1.3718
# Epoch 72/100
# 38/38 [==============================] - 0s 3ms/step - loss: 1.3111
# Epoch 73/100
# 38/38 [==============================] - 0s 3ms/step - loss: 1.1474
# Epoch 74/100
# 38/38 [==============================] - 0s 3ms/step - loss: 1.2589
# Epoch 75/100
# 38/38 [==============================] - 0s 3ms/step - loss: 2.9702
# Epoch 76/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.9212
# Epoch 77/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.7831
# Epoch 78/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.9627
# Epoch 79/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.9065
# Epoch 80/100
# 38/38 [==============================] - 0s 3ms/step - loss: 1.2484
# Epoch 81/100
# 38/38 [==============================] - 0s 3ms/step - loss: 1.8745
# Epoch 82/100
# 38/38 [==============================] - 0s 3ms/step - loss: 1.1420
# Epoch 83/100
# 38/38 [==============================] - 0s 3ms/step - loss: 1.0172
# Epoch 84/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.9471
# Epoch 85/100
# 38/38 [==============================] - 0s 3ms/step - loss: 1.2745
# Epoch 86/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.6821
# Epoch 87/100
# 38/38 [==============================] - 0s 3ms/step - loss: 1.0038
# Epoch 88/100
# 38/38 [==============================] - 0s 3ms/step - loss: 11.5699
# Epoch 89/100
# 38/38 [==============================] - 0s 3ms/step - loss: 5.3776
# Epoch 90/100
# 38/38 [==============================] - 0s 3ms/step - loss: 1.5953
# Epoch 91/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.7759
# Epoch 92/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.6859
# Epoch 93/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.6103
# Epoch 94/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.6362
# Epoch 95/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.6475
# Epoch 96/100
# 38/38 [==============================] - 0s 4ms/step - loss: 0.5078
# Epoch 97/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.9248
# Epoch 98/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5296
# Epoch 99/100
# 38/38 [==============================] - 0s 3ms/step - loss: 1.0755
# Epoch 100/100
# 38/38 [==============================] - 0s 3ms/step - loss: 2.4555
# Epoch 1/100
# 38/38 [==============================] - 2s 5ms/step - loss: 109.8770
# Epoch 2/100
# 38/38 [==============================] - 0s 4ms/step - loss: 5.3780
# Epoch 3/100
# 38/38 [==============================] - 0s 5ms/step - loss: 5.2836
# Epoch 4/100
# 38/38 [==============================] - 0s 4ms/step - loss: 5.3012
# Epoch 5/100
# 38/38 [==============================] - 0s 5ms/step - loss: 5.2670
# Epoch 6/100
# 38/38 [==============================] - 0s 4ms/step - loss: 5.2792
# Epoch 7/100
# 38/38 [==============================] - 0s 4ms/step - loss: 5.2188
# Epoch 8/100
# 38/38 [==============================] - 0s 4ms/step - loss: 5.1933
# Epoch 9/100
# 38/38 [==============================] - 0s 4ms/step - loss: 5.1837
# Epoch 10/100
# 38/38 [==============================] - 0s 4ms/step - loss: 5.2063
# Epoch 11/100
# 38/38 [==============================] - 0s 4ms/step - loss: 5.1875
# Epoch 12/100
# 38/38 [==============================] - 0s 4ms/step - loss: 5.1478
# Epoch 13/100
# 38/38 [==============================] - 0s 4ms/step - loss: 5.2215
# Epoch 14/100
# 38/38 [==============================] - 0s 3ms/step - loss: 5.2903
# Epoch 15/100
# 38/38 [==============================] - 0s 3ms/step - loss: 5.2096
# Epoch 16/100
# 38/38 [==============================] - 0s 3ms/step - loss: 5.2372
# Epoch 17/100
# 38/38 [==============================] - 0s 3ms/step - loss: 5.2769
# Epoch 18/100
# 38/38 [==============================] - 0s 3ms/step - loss: 5.2053
# Epoch 19/100
# 38/38 [==============================] - 0s 3ms/step - loss: 5.3644
# Epoch 20/100
# 38/38 [==============================] - 0s 3ms/step - loss: 5.3707
# Epoch 21/100
# 38/38 [==============================] - 0s 3ms/step - loss: 5.1826
# Epoch 22/100
# 38/38 [==============================] - 0s 3ms/step - loss: 5.4121
# Epoch 23/100
# 38/38 [==============================] - 0s 3ms/step - loss: 5.2047
# Epoch 24/100
# 38/38 [==============================] - 0s 3ms/step - loss: 5.4510
# Epoch 25/100
# 38/38 [==============================] - 0s 3ms/step - loss: 5.2727
# Epoch 26/100
# 38/38 [==============================] - 0s 3ms/step - loss: 5.1992
# Epoch 27/100
# 38/38 [==============================] - 0s 3ms/step - loss: 5.2252
# Epoch 28/100
# 38/38 [==============================] - 0s 3ms/step - loss: 5.3453
# Epoch 29/100
# 38/38 [==============================] - 0s 3ms/step - loss: 5.3916
# Epoch 30/100
# 38/38 [==============================] - 0s 3ms/step - loss: 5.3557
# Epoch 31/100
# 38/38 [==============================] - 0s 3ms/step - loss: 5.3045
# Epoch 32/100
# 38/38 [==============================] - 0s 3ms/step - loss: 5.4993
# Epoch 33/100
# 38/38 [==============================] - 0s 4ms/step - loss: 5.2813
# Epoch 34/100
# 38/38 [==============================] - 0s 3ms/step - loss: 5.2755
# Epoch 35/100
# 38/38 [==============================] - 0s 4ms/step - loss: 5.3812
# Epoch 36/100
# 38/38 [==============================] - 0s 3ms/step - loss: 5.3964
# Epoch 37/100
# 38/38 [==============================] - 0s 3ms/step - loss: 5.4118
# Epoch 38/100
# 38/38 [==============================] - 0s 3ms/step - loss: 5.2939
# Epoch 39/100
# 38/38 [==============================] - 0s 3ms/step - loss: 5.2737
# Epoch 40/100
# 38/38 [==============================] - 0s 3ms/step - loss: 5.2063
# Epoch 41/100
# 38/38 [==============================] - 0s 3ms/step - loss: 5.2169
# Epoch 42/100
# 38/38 [==============================] - 0s 3ms/step - loss: 5.1931
# Epoch 43/100
# 38/38 [==============================] - 0s 3ms/step - loss: 5.5281
# Epoch 44/100
# 38/38 [==============================] - 0s 3ms/step - loss: 5.2270
# Epoch 45/100
# 38/38 [==============================] - 0s 3ms/step - loss: 5.4699
# Epoch 46/100
# 38/38 [==============================] - 0s 3ms/step - loss: 5.5765
# Epoch 47/100
# 38/38 [==============================] - 0s 3ms/step - loss: 5.2616
# Epoch 48/100
# 38/38 [==============================] - 0s 3ms/step - loss: 5.5100
# Epoch 49/100
# 38/38 [==============================] - 0s 3ms/step - loss: 5.3473
# Epoch 50/100
# 38/38 [==============================] - 0s 3ms/step - loss: 5.2512
# Epoch 51/100
# 38/38 [==============================] - 0s 3ms/step - loss: 5.2435
# Epoch 52/100
# 38/38 [==============================] - 0s 3ms/step - loss: 5.2178
# Epoch 53/100
# 38/38 [==============================] - 0s 3ms/step - loss: 5.4206
# Epoch 54/100
# 38/38 [==============================] - 0s 3ms/step - loss: 5.3981
# Epoch 55/100
# 38/38 [==============================] - 0s 3ms/step - loss: 5.1698
# Epoch 56/100
# 38/38 [==============================] - 0s 3ms/step - loss: 5.2155
# Epoch 57/100
# 38/38 [==============================] - 0s 3ms/step - loss: 5.4055
# Epoch 58/100
# 38/38 [==============================] - 0s 3ms/step - loss: 5.2505
# Epoch 59/100
# 38/38 [==============================] - 0s 3ms/step - loss: 5.2404
# Epoch 60/100
# 38/38 [==============================] - 0s 7ms/step - loss: 5.2366
# Epoch 61/100
# 38/38 [==============================] - 0s 6ms/step - loss: 5.4516
# Epoch 62/100
# 38/38 [==============================] - 0s 3ms/step - loss: 5.4642
# Epoch 63/100
# 38/38 [==============================] - 0s 3ms/step - loss: 5.3079
# Epoch 64/100
# 38/38 [==============================] - 0s 3ms/step - loss: 5.2401
# Epoch 65/100
# 38/38 [==============================] - 0s 3ms/step - loss: 5.2871
# Epoch 66/100
# 38/38 [==============================] - 0s 5ms/step - loss: 5.4150
# Epoch 67/100
# 38/38 [==============================] - 0s 7ms/step - loss: 5.2974
# Epoch 68/100
# 38/38 [==============================] - 0s 5ms/step - loss: 5.2177
# Epoch 69/100
# 38/38 [==============================] - 0s 3ms/step - loss: 5.3118
# Epoch 70/100
# 38/38 [==============================] - 0s 3ms/step - loss: 5.1820
# Epoch 71/100
# 38/38 [==============================] - 0s 3ms/step - loss: 5.4915
# Epoch 72/100
# 38/38 [==============================] - 0s 5ms/step - loss: 5.9733
# Epoch 73/100
# 38/38 [==============================] - 0s 6ms/step - loss: 5.2639
# Epoch 74/100
# 38/38 [==============================] - 0s 6ms/step - loss: 5.3565
# Epoch 75/100
# 38/38 [==============================] - 0s 3ms/step - loss: 5.7897
# Epoch 76/100
# 38/38 [==============================] - 0s 3ms/step - loss: 5.6040
# Epoch 77/100
# 38/38 [==============================] - 0s 3ms/step - loss: 5.3794
# Epoch 78/100
# 38/38 [==============================] - 0s 3ms/step - loss: 5.2813
# Epoch 79/100
# 38/38 [==============================] - 0s 3ms/step - loss: 5.5403
# Epoch 80/100
# 38/38 [==============================] - 0s 3ms/step - loss: 5.2577
# Epoch 81/100
# 38/38 [==============================] - 0s 3ms/step - loss: 5.2279
# Epoch 82/100
# 38/38 [==============================] - 0s 3ms/step - loss: 5.3078
# Epoch 83/100
# 38/38 [==============================] - 0s 3ms/step - loss: 5.2784
# Epoch 84/100
# 38/38 [==============================] - 0s 3ms/step - loss: 5.3884
# Epoch 85/100
# 38/38 [==============================] - 0s 3ms/step - loss: 5.4143
# Epoch 86/100
# 38/38 [==============================] - 0s 3ms/step - loss: 5.3187
# Epoch 87/100
# 38/38 [==============================] - 0s 4ms/step - loss: 5.2364
# Epoch 88/100
# 38/38 [==============================] - 0s 4ms/step - loss: 5.1937
# Epoch 89/100
# 38/38 [==============================] - 0s 4ms/step - loss: 5.4960
# Epoch 90/100
# 38/38 [==============================] - 0s 4ms/step - loss: 5.7244
# Epoch 91/100
# 38/38 [==============================] - 0s 5ms/step - loss: 5.4302
# Epoch 92/100
# 38/38 [==============================] - 0s 5ms/step - loss: 5.2811
# Epoch 93/100
# 38/38 [==============================] - 0s 3ms/step - loss: 5.2919
# Epoch 94/100
# 38/38 [==============================] - 0s 4ms/step - loss: 5.2679
# Epoch 95/100
# 38/38 [==============================] - 0s 4ms/step - loss: 5.1467
# Epoch 96/100
# 38/38 [==============================] - 0s 4ms/step - loss: 5.4756
# Epoch 97/100
# 38/38 [==============================] - 0s 5ms/step - loss: 5.4138
# Epoch 98/100
# 38/38 [==============================] - 0s 5ms/step - loss: 5.3517
# Epoch 99/100
# 38/38 [==============================] - 0s 5ms/step - loss: 5.2166
# Epoch 100/100
# 38/38 [==============================] - 0s 4ms/step - loss: 5.1903
# 1/1 [==============================] - 0s 281ms/step
# 1/1 [==============================] - 0s 234ms/step
# Stacked LSTM - Actual Vibration on the 11th day: [[    1.69    12.06 -1028.63]
#  [   -7.66    14.37 -1028.32]
#  [   -1.13    10.25 -1028.11]
#  ...
#  [   -1.66     6.28 -1028.14]
#  [   -1.98     9.66 -1022.77]
#  [   -1.86    34.75 -1019.18]]
# Stacked LSTM - Predicted Vibration on the 11th day: [  -23.112484    26.081554 -1025.9944  ]
# Stacked LSTM - Vibration Error for the 11th day: [[24.80248398 14.02155441  2.63561523]
#  [15.45248398 11.71155441  2.32561523]
#  [21.98248398 15.83155441  2.11561523]
#  ...
#  [21.45248398 19.80155441  2.14561523]
#  [21.13248398 16.42155441  3.22438477]
#  [21.25248398  8.66844559  6.81438477]]
# Stacked LSTM - Mean Vibration Error for the 11th day:
#  [13.27509853  8.67347729  6.27848893]
#
# Stacked LSTM - Actual Temperature on the 11th day: 0       26.45
# 1       31.60
# 2       28.22
# 3       30.94
# 4       27.73
#         ...
# 1195    30.33
# 1196    26.44
# 1197    25.97
# 1198    25.68
# 1199    28.17
# Name: Temperature, Length: 1200, dtype: float64
# Stacked LSTM - Predicted Temperature on the 11th day: 29.041
# Stacked LSTM - Temperature Error for the 11th day: 0       2.591
# 1       2.559
# 2       0.821
# 3       1.899
# 4       1.311
#         ...
# 1195    1.289
# 1196    2.601
# 1197    3.071
# 1198    3.361
# 1199    0.871
# Name: Temperature, Length: 1200, dtype: float64
# Stacked LSTM - Mean Temperature Error for the 11th day:
#  2.019720010375977

# %%
from keras.models import Sequential
from keras.layers import Reshape, Conv1D, LSTM, Dense

# Assume X is a 2D array with shape (samples, features)

# Reshape X to include a time step dimension
X_reshaped = np.array(X).reshape(X.shape[0], X.shape[1], 1)

# Create ConvLSTM models
model_vibration = Sequential()
model_temperature = Sequential()

# Add Convolutional layer followed by LSTM layers to the models
model_vibration.add(Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=(X.shape[1], 1)))
model_vibration.add(LSTM(units=50, activation='relu'))
model_vibration.add(Dense(units=X.shape[1]))  # Output layer for vibration

model_temperature.add(Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=(X.shape[1], 1)))
model_temperature.add(LSTM(units=50, activation='relu'))
model_temperature.add(Dense(units=1))  # Output layer for temperature

# Compile the models
model_vibration.compile(optimizer='adam', loss='mean_squared_error')
model_temperature.compile(optimizer='adam', loss='mean_squared_error')

# Train the models
model_vibration.fit(X_reshaped, y_vibration, epochs=100, batch_size=32)
model_temperature.fit(X_reshaped, y_temperature, epochs=100, batch_size=32)

# Predict the 11th day values
X_11th_day_reshaped = np.array(X.iloc[[-1]]).reshape(1, X.shape[1], 1)
vibration_11th_day_prediction = model_vibration.predict(X_11th_day_reshaped)
temperature_11th_day_prediction = model_temperature.predict(X_11th_day_reshaped)

# Actual values for the 11th day
actual_vibration_11th_day = df_actual_values[['Vibration_X', 'Vibration_Y', 'Vibration_Z']].values
actual_temperature_11th_day = df_actual_values['Temperature']  # Replace with the actual value

# Calculate errors
vibration_error = np.abs(vibration_11th_day_prediction[0] - actual_vibration_11th_day)
temperature_error = np.abs(temperature_11th_day_prediction[0][0] - actual_temperature_11th_day)


mean_vibration_error = vibration_error.mean(axis=0)
mean_temperature_error = temperature_error.mean()

# Display results
print("ConvLSTM - Actual Vibration on the 11th day:", actual_vibration_11th_day)
print("ConvLSTM - Predicted Vibration on the 11th day:", vibration_11th_day_prediction[0])
print("ConvLSTM - Vibration Error for the 11th day:", vibration_error)
print("ConvLSTM - Mean Vibration Error for the 11th day: \n", mean_vibration_error)


print("\nConvLSTM - Actual Temperature on the 11th day:", actual_temperature_11th_day)
print("ConvLSTM - Predicted Temperature on the 11th day:", temperature_11th_day_prediction[0][0])
print("ConvLSTM - Temperature Error for the 11th day:", temperature_error)
print("ConvLSTM - Mean Temperature Error for the 11th day: \n", mean_temperature_error)




# Actual values for the 11th day
# Out:
# Epoch 1/100
# 38/38 [==============================] - 1s 2ms/step - loss: 253392.1562
# Epoch 2/100
# 38/38 [==============================] - 0s 2ms/step - loss: 95272.2656
# Epoch 3/100
# 38/38 [==============================] - 0s 2ms/step - loss: 11214.6504
# Epoch 4/100
# 38/38 [==============================] - 0s 2ms/step - loss: 456.1640
# Epoch 5/100
# 38/38 [==============================] - 0s 2ms/step - loss: 61.3530
# Epoch 6/100
# 38/38 [==============================] - 0s 2ms/step - loss: 60.8623
# Epoch 7/100
# 38/38 [==============================] - 0s 2ms/step - loss: 60.9853
# Epoch 8/100
# 38/38 [==============================] - 0s 2ms/step - loss: 60.8558
# Epoch 9/100
# 38/38 [==============================] - 0s 2ms/step - loss: 60.2923
# Epoch 10/100
# 38/38 [==============================] - 0s 2ms/step - loss: 60.1881
# Epoch 11/100
# 38/38 [==============================] - 0s 2ms/step - loss: 60.2527
# Epoch 12/100
# 38/38 [==============================] - 0s 2ms/step - loss: 60.1737
# Epoch 13/100
# 38/38 [==============================] - 0s 2ms/step - loss: 59.7317
# Epoch 14/100
# 38/38 [==============================] - 0s 2ms/step - loss: 59.7213
# Epoch 15/100
# 38/38 [==============================] - 0s 2ms/step - loss: 58.9309
# Epoch 16/100
# 38/38 [==============================] - 0s 2ms/step - loss: 59.3105
# Epoch 17/100
# 38/38 [==============================] - 0s 2ms/step - loss: 58.6901
# Epoch 18/100
# 38/38 [==============================] - 0s 2ms/step - loss: 58.5926
# Epoch 19/100
# 38/38 [==============================] - 0s 2ms/step - loss: 58.1918
# Epoch 20/100
# 38/38 [==============================] - 0s 2ms/step - loss: 57.9098
# Epoch 21/100
# 38/38 [==============================] - 0s 2ms/step - loss: 57.6744
# Epoch 22/100
# 38/38 [==============================] - 0s 2ms/step - loss: 57.4597
# Epoch 23/100
# 38/38 [==============================] - 0s 2ms/step - loss: 56.9004
# Epoch 24/100
# 38/38 [==============================] - 0s 2ms/step - loss: 57.0183
# Epoch 25/100
# 38/38 [==============================] - 0s 2ms/step - loss: 56.7953
# Epoch 26/100
# 38/38 [==============================] - 0s 2ms/step - loss: 58.0500
# Epoch 27/100
# 38/38 [==============================] - 0s 2ms/step - loss: 56.0091
# Epoch 28/100
# 38/38 [==============================] - 0s 2ms/step - loss: 55.1918
# Epoch 29/100
# 38/38 [==============================] - 0s 2ms/step - loss: 54.7478
# Epoch 30/100
# 38/38 [==============================] - 0s 2ms/step - loss: 54.7787
# Epoch 31/100
# 38/38 [==============================] - 0s 2ms/step - loss: 54.0872
# Epoch 32/100
# 38/38 [==============================] - 0s 2ms/step - loss: 54.3187
# Epoch 33/100
# 38/38 [==============================] - 0s 2ms/step - loss: 53.7726
# Epoch 34/100
# 38/38 [==============================] - 0s 2ms/step - loss: 53.4077
# Epoch 35/100
# 38/38 [==============================] - 0s 2ms/step - loss: 53.6337
# Epoch 36/100
# 38/38 [==============================] - 0s 2ms/step - loss: 51.8830
# Epoch 37/100
# 38/38 [==============================] - 0s 2ms/step - loss: 51.6313
# Epoch 38/100
# 38/38 [==============================] - 0s 2ms/step - loss: 50.9350
# Epoch 39/100
# 38/38 [==============================] - 0s 2ms/step - loss: 50.1649
# Epoch 40/100
# 38/38 [==============================] - 0s 2ms/step - loss: 52.2771
# Epoch 41/100
# 38/38 [==============================] - 0s 2ms/step - loss: 49.2515
# Epoch 42/100
# 38/38 [==============================] - 0s 2ms/step - loss: 49.8920
# Epoch 43/100
# 38/38 [==============================] - 0s 2ms/step - loss: 48.2221
# Epoch 44/100
# 38/38 [==============================] - 0s 2ms/step - loss: 47.5132
# Epoch 45/100
# 38/38 [==============================] - 0s 2ms/step - loss: 46.8547
# Epoch 46/100
# 38/38 [==============================] - 0s 2ms/step - loss: 46.2495
# Epoch 47/100
# 38/38 [==============================] - 0s 2ms/step - loss: 45.0462
# Epoch 48/100
# 38/38 [==============================] - 0s 2ms/step - loss: 44.4175
# Epoch 49/100
# 38/38 [==============================] - 0s 2ms/step - loss: 43.4656
# Epoch 50/100
# 38/38 [==============================] - 0s 2ms/step - loss: 42.7082
# Epoch 51/100
# 38/38 [==============================] - 0s 2ms/step - loss: 41.7230
# Epoch 52/100
# 38/38 [==============================] - 0s 2ms/step - loss: 40.6550
# Epoch 53/100
# 38/38 [==============================] - 0s 2ms/step - loss: 40.0490
# Epoch 54/100
# 38/38 [==============================] - 0s 2ms/step - loss: 39.3169
# Epoch 55/100
# 38/38 [==============================] - 0s 2ms/step - loss: 37.8867
# Epoch 56/100
# 38/38 [==============================] - 0s 2ms/step - loss: 37.3972
# Epoch 57/100
# 38/38 [==============================] - 0s 2ms/step - loss: 36.1514
# Epoch 58/100
# 38/38 [==============================] - 0s 2ms/step - loss: 35.8444
# Epoch 59/100
# 38/38 [==============================] - 0s 2ms/step - loss: 35.1244
# Epoch 60/100
# 38/38 [==============================] - 0s 2ms/step - loss: 33.1765
# Epoch 61/100
# 38/38 [==============================] - 0s 2ms/step - loss: 32.1141
# Epoch 62/100
# 38/38 [==============================] - 0s 2ms/step - loss: 31.4635
# Epoch 63/100
# 38/38 [==============================] - 0s 2ms/step - loss: 30.5926
# Epoch 64/100
# 38/38 [==============================] - 0s 2ms/step - loss: 29.8796
# Epoch 65/100
# 38/38 [==============================] - 0s 2ms/step - loss: 28.8678
# Epoch 66/100
# 38/38 [==============================] - 0s 2ms/step - loss: 28.6791
# Epoch 67/100
# 38/38 [==============================] - 0s 2ms/step - loss: 27.9816
# Epoch 68/100
# 38/38 [==============================] - 0s 2ms/step - loss: 26.3778
# Epoch 69/100
# 38/38 [==============================] - 0s 2ms/step - loss: 25.8865
# Epoch 70/100
# 38/38 [==============================] - 0s 2ms/step - loss: 25.3736
# Epoch 71/100
# 38/38 [==============================] - 0s 2ms/step - loss: 24.4788
# Epoch 72/100
# 38/38 [==============================] - 0s 2ms/step - loss: 24.7270
# Epoch 73/100
# 38/38 [==============================] - 0s 2ms/step - loss: 23.3431
# Epoch 74/100
# 38/38 [==============================] - 0s 2ms/step - loss: 22.6941
# Epoch 75/100
# 38/38 [==============================] - 0s 2ms/step - loss: 22.5687
# Epoch 76/100
# 38/38 [==============================] - 0s 2ms/step - loss: 22.0243
# Epoch 77/100
# 38/38 [==============================] - 0s 2ms/step - loss: 21.0747
# Epoch 78/100
# 38/38 [==============================] - 0s 2ms/step - loss: 21.4728
# Epoch 79/100
# 38/38 [==============================] - 0s 2ms/step - loss: 20.5787
# Epoch 80/100
# 38/38 [==============================] - 0s 2ms/step - loss: 20.1534
# Epoch 81/100
# 38/38 [==============================] - 0s 2ms/step - loss: 19.5787
# Epoch 82/100
# 38/38 [==============================] - 0s 2ms/step - loss: 19.2133
# Epoch 83/100
# 38/38 [==============================] - 0s 2ms/step - loss: 18.8020
# Epoch 84/100
# 38/38 [==============================] - 0s 2ms/step - loss: 18.6607
# Epoch 85/100
# 38/38 [==============================] - 0s 2ms/step - loss: 18.1984
# Epoch 86/100
# 38/38 [==============================] - 0s 2ms/step - loss: 17.6275
# Epoch 87/100
# 38/38 [==============================] - 0s 2ms/step - loss: 18.0537
# Epoch 88/100
# 38/38 [==============================] - 0s 2ms/step - loss: 17.2072
# Epoch 89/100
# 38/38 [==============================] - 0s 2ms/step - loss: 16.6169
# Epoch 90/100
# 38/38 [==============================] - 0s 2ms/step - loss: 16.9744
# Epoch 91/100
# 38/38 [==============================] - 0s 2ms/step - loss: 16.2674
# Epoch 92/100
# 38/38 [==============================] - 0s 2ms/step - loss: 15.8441
# Epoch 93/100
# 38/38 [==============================] - 0s 2ms/step - loss: 15.8381
# Epoch 94/100
# 38/38 [==============================] - 0s 2ms/step - loss: 15.9979
# Epoch 95/100
# 38/38 [==============================] - 0s 2ms/step - loss: 15.1503
# Epoch 96/100
# 38/38 [==============================] - 0s 2ms/step - loss: 14.9789
# Epoch 97/100
# 38/38 [==============================] - 0s 2ms/step - loss: 14.6039
# Epoch 98/100
# 38/38 [==============================] - 0s 2ms/step - loss: 14.5512
# Epoch 99/100
# 38/38 [==============================] - 0s 2ms/step - loss: 13.8073
# Epoch 100/100
# 38/38 [==============================] - 0s 2ms/step - loss: 13.6101
# Epoch 1/100
# 38/38 [==============================] - 1s 2ms/step - loss: 63.1253
# Epoch 2/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.6421
# Epoch 3/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.2338
# Epoch 4/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.4010
# Epoch 5/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.2786
# Epoch 6/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.2051
# Epoch 7/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.2256
# Epoch 8/100
# 38/38 [==============================] - 0s 3ms/step - loss: 5.1933
# Epoch 9/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.5235
# Epoch 10/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.2506
# Epoch 11/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.2486
# Epoch 12/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.2409
# Epoch 13/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.2710
# Epoch 14/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.2495
# Epoch 15/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.2655
# Epoch 16/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.2591
# Epoch 17/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.3061
# Epoch 18/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.2039
# Epoch 19/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.3452
# Epoch 20/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.2284
# Epoch 21/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.3175
# Epoch 22/100
# 38/38 [==============================] - 0s 3ms/step - loss: 5.2307
# Epoch 23/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.4363
# Epoch 24/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.3218
# Epoch 25/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.2399
# Epoch 26/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.5352
# Epoch 27/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.3706
# Epoch 28/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.3432
# Epoch 29/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.3009
# Epoch 30/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.4324
# Epoch 31/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.2125
# Epoch 32/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.2545
# Epoch 33/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.5502
# Epoch 34/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.3180
# Epoch 35/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.4644
# Epoch 36/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.3661
# Epoch 37/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.3238
# Epoch 38/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.4412
# Epoch 39/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.3589
# Epoch 40/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.3321
# Epoch 41/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.2743
# Epoch 42/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.3292
# Epoch 43/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.4705
# Epoch 44/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.2935
# Epoch 45/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.4200
# Epoch 46/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.4650
# Epoch 47/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.2170
# Epoch 48/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.3597
# Epoch 49/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.2309
# Epoch 50/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.3784
# Epoch 51/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.4045
# Epoch 52/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.2521
# Epoch 53/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.2993
# Epoch 54/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.3849
# Epoch 55/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.2845
# Epoch 56/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.7272
# Epoch 57/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.7740
# Epoch 58/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.9422
# Epoch 59/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.2019
# Epoch 60/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.4103
# Epoch 61/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.4235
# Epoch 62/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.7446
# Epoch 63/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.7529
# Epoch 64/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.2977
# Epoch 65/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.2614
# Epoch 66/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.5997
# Epoch 67/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.8037
# Epoch 68/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.6269
# Epoch 69/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.4879
# Epoch 70/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.5169
# Epoch 71/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.5494
# Epoch 72/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.2422
# Epoch 73/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.3104
# Epoch 74/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.2842
# Epoch 75/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.6045
# Epoch 76/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.4272
# Epoch 77/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.3932
# Epoch 78/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.4182
# Epoch 79/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.4179
# Epoch 80/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.5161
# Epoch 81/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.3381
# Epoch 82/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.2230
# Epoch 83/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.2443
# Epoch 84/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.2108
# Epoch 85/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.4682
# Epoch 86/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.6681
# Epoch 87/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.4313
# Epoch 88/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.3116
# Epoch 89/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.4592
# Epoch 90/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.2846
# Epoch 91/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.4194
# Epoch 92/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.8036
# Epoch 93/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.6693
# Epoch 94/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.3223
# Epoch 95/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.6321
# Epoch 96/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.2904
# Epoch 97/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.9358
# Epoch 98/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.2641
# Epoch 99/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.4423
# Epoch 100/100
# 38/38 [==============================] - 0s 2ms/step - loss: 5.6477
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 123ms/step
# ConvLSTM - Actual Vibration on the 11th day: [[    1.69    12.06 -1028.63]
#  [   -7.66    14.37 -1028.32]
#  [   -1.13    10.25 -1028.11]
#  ...
#  [   -1.66     6.28 -1028.14]
#  [   -1.98     9.66 -1022.77]
#  [   -1.86    34.75 -1019.18]]
# ConvLSTM - Predicted Vibration on the 11th day: [  -19.72136     16.941668 -1029.497   ]
# ConvLSTM - Vibration Error for the 11th day: [[21.41135925  4.88166756  0.86694824]
#  [12.06135925  2.57166756  1.17694824]
#  [18.59135925  6.69166756  1.38694824]
#  ...
#  [18.06135925 10.66166756  1.35694824]
#  [17.74135925  7.28166756  6.72694824]
#  [17.86135925 17.80833244 10.31694824]]
# ConvLSTM - Mean Vibration Error for the 11th day:
#  [10.64350843  7.56784426  8.88419109]
#
# ConvLSTM - Actual Temperature on the 11th day: 0       26.45
# 1       31.60
# 2       28.22
# 3       30.94
# 4       27.73
#         ...
# 1195    30.33
# 1196    26.44
# 1197    25.97
# 1198    25.68
# 1199    28.17
# Name: Temperature, Length: 1200, dtype: float64
# ConvLSTM - Predicted Temperature on the 11th day: 29.679125
# ConvLSTM - Temperature Error for the 11th day: 0       3.229125
# 1       1.920875
# 2       1.459125
# 3       1.260875
# 4       1.949125
#           ...
# 1195    0.650875
# 1196    3.239125
# 1197    3.709125
# 1198    3.999125
# 1199    1.509125
# Name: Temperature, Length: 1200, dtype: float64
# ConvLSTM - Mean Temperature Error for the 11th day:
#  2.0883051789601645
